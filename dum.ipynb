# %%
# %matplotlib widget
# %run test_groundtruth.py
# Out:
# t_sigmas=array([31.0481882 , 30.41364809, 31.62261833]), t_sigmas**2=array([963.98999023, 924.98999023, 999.98999023])
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 40/40 [00:39<00:00,  1.02it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/graylab/diffusion_energies/DiffEnergy/test_groundtruth.py:135
#     133 fig,ax = plt.subplots(subplot_kw={"projection":"3d"})
#     134 tm,xm = np.meshgrid(times,x)
# --> 135 ax.plot_surface(xm,tm,errors,label="score_error")
#     136 ax.set_xlabel("X")
#     137 ax.set_ylabel("t")
#
# NameError: name 'errors' is not defined
