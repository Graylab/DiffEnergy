# %%
# %run test_groundtruth.py
import matplotlib.pyplot as plt
plt.ylabel("Prior Density $p_1(x_1)$",fontsize='large')
plt.legend()
plt.savefig("priors.png",dpi=600)
# Out:
# t_sigmas=array([23.87969829, 23.048644  , 24.62194124]), t_sigmas**2=array([570.23999023, 531.23999023, 606.23999023])
